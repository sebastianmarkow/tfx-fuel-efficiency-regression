# %%
import json
import pprint
import datetime

import ml_metadata
import pandas as pd

from ml_metadata import metadata_store
from ml_metadata.proto import metadata_store_pb2

# %%
print(ml_metadata.__version__)
# Out:
# 0.29.0

# %%
pp = pprint.PrettyPrinter(indent=4)

# %%
connection_config = metadata_store_pb2.ConnectionConfig(mysql=metadata_store_pb2.MySQLDatabaseConfig(
    database='mlmd',
    host='mlmddb',
    user='mysql',
    password='mysql',
    port=3306,
))
store = metadata_store.MetadataStore(connection_config)

# %%
def _parse_custom_value(value):
    if value.HasField('int_value'):
        return value.int_value
    elif value.HasField('double_value'):
        return value.double_value
    else:
        return _py_value(value.string_value)
    
    
def _py_value(val):
    try:
        return json.loads(val.lower())
    except ValueError:
        return val

# %%
def _get_run_info_from_artifact(store, identifier):
    executions_to_artifact = {}
    events = store.get_events_by_artifact_ids([identifier])
    for event in events:
        executions_to_artifact[event.execution_id] = event.artifact_id
    
    artifact_to_run_info = {}
    executions = store.get_executions_by_id(list(executions_to_artifact.keys()))
    for execution in executions:
        artifact_id = executions_to_artifact[execution.id]
        artifact_to_run_info[artifact_id] = {
            'started_at': datetime.datetime.fromtimestamp(execution.create_time_since_epoch // 1000),
            'last_update': datetime.datetime.fromtimestamp(execution.last_update_time_since_epoch // 1000),
        }
    return artifact_to_run_info

# %%
artifacts = store.get_artifacts_by_type("io.markow.TrackingResult")

metrics = {}
property_ids = set()

for artifact in artifacts:
    custom_values = {}
    properties = {}
    
    for k, v in artifact.custom_properties.items():
        custom_values[k] = _parse_custom_value(v)
        if k == 'name':
            namespaces = _parse_custom_value(v).split(':')
            custom_values['pipeline'] = namespaces[0]
            custom_values['run_id'] = namespaces[1]
            custom_values['model'] = namespaces[2].split('.')[1]
            
    property_ids = property_ids.union(custom_values.keys())
    
    run_info = _get_run_info_from_artifact(store, artifact.id)
    custom_values.update(run_info[artifact.id])
    

    metrics[artifact.id] = custom_values
    
return metrics, property_ids
    
pp.pprint(metrics)

pd.DataFrame(metrics.values())
# Out:
# {   11: {   'example_count': 2.0,
#             'last_update': datetime.datetime(2021, 5, 3, 8, 42, 28),
#             'loss': 2.803909,
#             'mae': 2.803909,
#             'mean_absolute_error': 2.803909,
#             'model': 'regression_simple',
#             'name': 'auto-mpg-postgres:20210503-084041.665048:TrackingPublisher.regression_simple:tracking_results:0',
#             'pipeline': 'auto-mpg-postgres',
#             'run_id': '20210503-084041.665048',
#             'started_at': datetime.datetime(2021, 5, 3, 8, 42, 27),
#             'tfx_version': '0.29.0',
#             'weighted_example_count': 2.0},
#     23: {   'example_count': 4.0,
#             'last_update': datetime.datetime(2021, 5, 3, 8, 45, 35),
#             'loss': 0.938006,
#             'mae': 0.938006,
#             'mean_absolute_error': 0.938006,
#             'model': 'regression_dnn',
#             'name': 'auto-mpg-postgres:20210503-084342.683215:TrackingPublisher.regression_dnn:tracking_results:0',
#             'pipeline': 'auto-mpg-postgres',
#             'run_id': '20210503-084342.683215',
#             'started_at': datetime.datetime(2021, 5, 3, 8, 45, 33),
#             'tfx_version': '0.29.0',
#             'weighted_example_count': 4.0},
#     35: {   'example_count': 2.0,
#             'last_update': datetime.datetime(2021, 5, 3, 8, 52, 34),
#             'loss': 1.399343,
#             'mae': 1.399343,
#             'mean_absolute_error': 1.399343,
#             'model': 'regression_dnn',
#             'name': 'auto-mpg-postgres:20210503-085031.896911:TrackingPublisher.regression_dnn:tracking_results:0',
#             'pipeline': 'auto-mpg-postgres',
#             'run_id': '20210503-085031.896911',
#             'started_at': datetime.datetime(2021, 5, 3, 8, 52, 32),
#             'tfx_version': '0.29.0',
#             'weighted_example_count': 2.0},
#     64: {   'example_count': 77.0,
#             'last_update': datetime.datetime(2021, 5, 3, 9, 53, 29),
#             'loss': 2.203678,
#             'mae': 2.203678,
#             'mean_absolute_error': 2.203678,
#             'model': 'regression_dnn',
#             'name': 'auto-mpg-postgres:20210503-095139.719179:TrackingPublisher.regression_dnn:tracking_results:0',
#             'pipeline': 'auto-mpg-postgres',
#             'run_id': '20210503-095139.719179',
#             'started_at': datetime.datetime(2021, 5, 3, 9, 53, 27),
#             'tfx_version': '0.29.0',
#             'weighted_example_count': 77.0},
#     84: {   'example_count': 2.0,
#             'last_update': datetime.datetime(2021, 5, 3, 9, 59, 38),
#             'loss': 1.179773,
#             'mae': 1.179773,
#             'mean_absolute_error': 1.179773,
#             'model': 'regression_dnn',
#             'name': 'auto-mpg-postgres:20210503-095732.394489:TrackingPublisher.regression_dnn:tracking_results:0',
#             'pipeline': 'auto-mpg-postgres',
#             'run_id': '20210503-095732.394489',
#             'started_at': datetime.datetime(2021, 5, 3, 9, 59, 37),
#             'tfx_version': '0.29.0',
#             'weighted_example_count': 2.0},
#     96: {   'example_count': 73.0,
#             'last_update': datetime.datetime(2021, 5, 3, 10, 2, 10),
#             'loss': 1.702325,
#             'mae': 1.702325,
#             'mean_absolute_error': 1.702325,
#             'model': 'regression_dnn',
#             'name': 'auto-mpg-postgres:20210503-100010.050209:TrackingPublisher.regression_dnn:tracking_results:0',
#             'pipeline': 'auto-mpg-postgres',
#             'run_id': '20210503-100010.050209',
#             'started_at': datetime.datetime(2021, 5, 3, 10, 2, 8),
#             'tfx_version': '0.29.0',
#             'weighted_example_count': 73.0},
#     107: {   'example_count': 1.0,
#              'last_update': datetime.datetime(2021, 5, 3, 10, 4, 36),
#              'loss': 2.332426,
#              'mae': 2.332426,
#              'mean_absolute_error': 2.332426,
#              'model': 'regression_dnn',
#              'name': 'auto-mpg-postgres:20210503-100241.363067:TrackingPublisher.regression_dnn:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-100241.363067',
#              'started_at': datetime.datetime(2021, 5, 3, 10, 4, 34),
#              'tfx_version': '0.29.0',
#              'weighted_example_count': 1.0},
#     119: {   'example_count': 1.0,
#              'last_update': datetime.datetime(2021, 5, 3, 10, 10, 1),
#              'loss': 3.773273,
#              'mae': 3.773273,
#              'mean_absolute_error': 3.773273,
#              'model': 'regression_dnn',
#              'name': 'auto-mpg-postgres:20210503-100803.860371:TrackingPublisher.regression_dnn:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-100803.860371',
#              'started_at': datetime.datetime(2021, 5, 3, 10, 10),
#              'tfx_version': '0.29.0',
#              'weighted_example_count': 1.0},
#     131: {   'example_count': 4.0,
#              'last_update': datetime.datetime(2021, 5, 3, 10, 14, 21),
#              'loss': 1.009556,
#              'mae': 1.009556,
#              'mean_absolute_error': 1.009556,
#              'model': 'regression_dnn',
#              'name': 'auto-mpg-postgres:20210503-101218.554732:TrackingPublisher.regression_dnn:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-101218.554732',
#              'started_at': datetime.datetime(2021, 5, 3, 10, 14, 20),
#              'tfx_version': '0.29.0',
#              'weighted_example_count': 4.0},
#     144: {   'last_update': datetime.datetime(2021, 5, 3, 10, 23, 21),
#              'loss': 1.930636,
#              'mean_absolute_error': 1.930636,
#              'model': 'regression_dnn',
#              'name': 'auto-mpg-postgres:20210503-102124.944080:TrackingPublisher.regression_dnn:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-102124.944080',
#              'started_at': datetime.datetime(2021, 5, 3, 10, 23, 19),
#              'tfx_version': '0.29.0'},
#     155: {   'example_count': 84.0,
#              'last_update': datetime.datetime(2021, 5, 3, 10, 25, 52),
#              'loss': 1.999311,
#              'mean_absolute_error': 1.999311,
#              'model': 'regression_dnn',
#              'name': 'auto-mpg-postgres:20210503-102406.188624:TrackingPublisher.regression_dnn:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-102406.188624',
#              'started_at': datetime.datetime(2021, 5, 3, 10, 25, 51),
#              'tfx_version': '0.29.0'},
#     168: {   'example_count': 84.0,
#              'last_update': datetime.datetime(2021, 5, 3, 10, 29, 36),
#              'loss': 1.832451,
#              'mean_absolute_error': 1.832451,
#              'model': 'regression_dnn',
#              'name': 'auto-mpg-postgres:20210503-102745.642684:TrackingPublisher.regression_dnn:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-102745.642684',
#              'started_at': datetime.datetime(2021, 5, 3, 10, 29, 34),
#              'tfx_version': '0.29.0'},
#     180: {   'example_count': 3.0,
#              'last_update': datetime.datetime(2021, 5, 3, 10, 40, 47),
#              'loss': 3.157531,
#              'mean_absolute_error': 3.157531,
#              'model': 'regression_dnn',
#              'name': 'auto-mpg-postgres:20210503-103853.212040:TrackingPublisher.regression_dnn:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-103853.212040',
#              'started_at': datetime.datetime(2021, 5, 3, 10, 40, 45),
#              'tfx_version': '0.29.0'},
#     192: {   'example_count': 84.0,
#              'last_update': datetime.datetime(2021, 5, 3, 10, 43, 18),
#              'loss': 1.935876,
#              'mean_absolute_error': 1.935876,
#              'model': 'regression_dnn',
#              'name': 'auto-mpg-postgres:20210503-104125.242540:TrackingPublisher.regression_dnn:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-104125.242540',
#              'started_at': datetime.datetime(2021, 5, 3, 10, 43, 16),
#              'tfx_version': '0.29.0'},
#     203: {   'example_count': 84.0,
#              'last_update': datetime.datetime(2021, 5, 3, 10, 47, 18),
#              'loss': 2.59753,
#              'mean_absolute_error': 2.59753,
#              'model': 'regression_simple',
#              'name': 'auto-mpg-postgres:20210503-104528.091495:TrackingPublisher.regression_simple:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-104528.091495',
#              'started_at': datetime.datetime(2021, 5, 3, 10, 47, 16),
#              'tfx_version': '0.29.0'},
#     208: {   'example_count': 84.0,
#              'last_update': datetime.datetime(2021, 5, 3, 10, 48, 10),
#              'loss': 1.888613,
#              'mean_absolute_error': 1.888613,
#              'model': 'regression_dnn',
#              'name': 'auto-mpg-postgres:20210503-104528.091495:TrackingPublisher.regression_dnn:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-104528.091495',
#              'started_at': datetime.datetime(2021, 5, 3, 10, 48, 8),
#              'tfx_version': '0.29.0'},
#     238: {   'example_count': 84.0,
#              'last_update': datetime.datetime(2021, 5, 3, 11, 1, 1),
#              'loss': 2.572515,
#              'mean_absolute_error': 2.572515,
#              'model': 'regression_simple',
#              'name': 'auto-mpg-postgres:20210503-105908.893522:TrackingPublisher.regression_simple:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-105908.893522',
#              'started_at': datetime.datetime(2021, 5, 3, 11, 0, 59),
#              'tfx_version': '0.29.0'},
#     244: {   'example_count': 84.0,
#              'last_update': datetime.datetime(2021, 5, 3, 11, 1, 53),
#              'loss': 1.943397,
#              'mean_absolute_error': 1.943397,
#              'model': 'regression_dnn',
#              'name': 'auto-mpg-postgres:20210503-105908.893522:TrackingPublisher.regression_dnn:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-105908.893522',
#              'started_at': datetime.datetime(2021, 5, 3, 11, 1, 52),
#              'tfx_version': '0.29.0'},
#     255: {   'example_count': 73.0,
#              'last_update': datetime.datetime(2021, 5, 3, 11, 4, 40),
#              'loss': 2.748948,
#              'mean_absolute_error': 2.748948,
#              'model': 'regression_simple',
#              'name': 'auto-mpg-postgres:20210503-110253.357855:TrackingPublisher.regression_simple:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-110253.357855',
#              'started_at': datetime.datetime(2021, 5, 3, 11, 4, 39),
#              'tfx_version': '0.29.0'},
#     260: {   'example_count': 73.0,
#              'last_update': datetime.datetime(2021, 5, 3, 11, 5, 29),
#              'loss': 1.722986,
#              'mean_absolute_error': 1.722987,
#              'model': 'regression_dnn',
#              'name': 'auto-mpg-postgres:20210503-110253.357855:TrackingPublisher.regression_dnn:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-110253.357855',
#              'started_at': datetime.datetime(2021, 5, 3, 11, 5, 27),
#              'tfx_version': '0.29.0'},
#     272: {   'example_count': 73.0,
#              'last_update': datetime.datetime(2021, 5, 3, 11, 8, 41),
#              'loss': 1.778732,
#              'mean_absolute_error': 1.778732,
#              'model': 'regression_dnn',
#              'name': 'auto-mpg-postgres:20210503-110652.892518:TrackingPublisher.regression_dnn:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-110652.892518',
#              'started_at': datetime.datetime(2021, 5, 3, 11, 8, 39),
#              'tfx_version': '0.29.0'},
#     277: {   'example_count': 73.0,
#              'last_update': datetime.datetime(2021, 5, 3, 11, 9, 24),
#              'loss': 2.719088,
#              'mean_absolute_error': 2.719088,
#              'model': 'regression_simple',
#              'name': 'auto-mpg-postgres:20210503-110652.892518:TrackingPublisher.regression_simple:tracking_results:0',
#              'pipeline': 'auto-mpg-postgres',
#              'run_id': '20210503-110652.892518',
#              'started_at': datetime.datetime(2021, 5, 3, 11, 9, 23),
#              'tfx_version': '0.29.0'}}
#          mae  weighted_example_count  example_count tfx_version      loss  \
# 0   2.803909                     2.0            2.0      0.29.0  2.803909
# 1   0.938006                     4.0            4.0      0.29.0  0.938006
# 2   1.399343                     2.0            2.0      0.29.0  1.399343
# 3   2.203678                    77.0           77.0      0.29.0  2.203678
# 4   1.179773                     2.0            2.0      0.29.0  1.179773
# 5   1.702325                    73.0           73.0      0.29.0  1.702325
# 6   2.332426                     1.0            1.0      0.29.0  2.332426
# 7   3.773273                     1.0            1.0      0.29.0  3.773273
# 8   1.009556                     4.0            4.0      0.29.0  1.009556
# 9        NaN                     NaN            NaN      0.29.0  1.930636
# 10       NaN                     NaN           84.0      0.29.0  1.999311
# 11       NaN                     NaN           84.0      0.29.0  1.832451
# 12       NaN                     NaN            3.0      0.29.0  3.157531
# 13       NaN                     NaN           84.0      0.29.0  1.935876
# 14       NaN                     NaN           84.0      0.29.0  2.597530
# 15       NaN                     NaN           84.0      0.29.0  1.888613
# 16       NaN                     NaN           84.0      0.29.0  2.572515
# 17       NaN                     NaN           84.0      0.29.0  1.943397
# 18       NaN                     NaN           73.0      0.29.0  2.748948
# 19       NaN                     NaN           73.0      0.29.0  1.722986
# 20       NaN                     NaN           73.0      0.29.0  1.778732
# 21       NaN                     NaN           73.0      0.29.0  2.719088
#
#     mean_absolute_error                                               name  \
# 0              2.803909  auto-mpg-postgres:20210503-084041.665048:Track...
# 1              0.938006  auto-mpg-postgres:20210503-084342.683215:Track...
# 2              1.399343  auto-mpg-postgres:20210503-085031.896911:Track...
# 3              2.203678  auto-mpg-postgres:20210503-095139.719179:Track...
# 4              1.179773  auto-mpg-postgres:20210503-095732.394489:Track...
# 5              1.702325  auto-mpg-postgres:20210503-100010.050209:Track...
# 6              2.332426  auto-mpg-postgres:20210503-100241.363067:Track...
# 7              3.773273  auto-mpg-postgres:20210503-100803.860371:Track...
# 8              1.009556  auto-mpg-postgres:20210503-101218.554732:Track...
# 9              1.930636  auto-mpg-postgres:20210503-102124.944080:Track...
# 10             1.999311  auto-mpg-postgres:20210503-102406.188624:Track...
# 11             1.832451  auto-mpg-postgres:20210503-102745.642684:Track...
# 12             3.157531  auto-mpg-postgres:20210503-103853.212040:Track...
# 13             1.935876  auto-mpg-postgres:20210503-104125.242540:Track...
# 14             2.597530  auto-mpg-postgres:20210503-104528.091495:Track...
# 15             1.888613  auto-mpg-postgres:20210503-104528.091495:Track...
# 16             2.572515  auto-mpg-postgres:20210503-105908.893522:Track...
# 17             1.943397  auto-mpg-postgres:20210503-105908.893522:Track...
# 18             2.748948  auto-mpg-postgres:20210503-110253.357855:Track...
# 19             1.722987  auto-mpg-postgres:20210503-110253.357855:Track...
# 20             1.778732  auto-mpg-postgres:20210503-110652.892518:Track...
# 21             2.719088  auto-mpg-postgres:20210503-110652.892518:Track...
#
#              pipeline                  run_id              model  \
# 0   auto-mpg-postgres  20210503-084041.665048  regression_simple
# 1   auto-mpg-postgres  20210503-084342.683215     regression_dnn
# 2   auto-mpg-postgres  20210503-085031.896911     regression_dnn
# 3   auto-mpg-postgres  20210503-095139.719179     regression_dnn
# 4   auto-mpg-postgres  20210503-095732.394489     regression_dnn
# 5   auto-mpg-postgres  20210503-100010.050209     regression_dnn
# 6   auto-mpg-postgres  20210503-100241.363067     regression_dnn
# 7   auto-mpg-postgres  20210503-100803.860371     regression_dnn
# 8   auto-mpg-postgres  20210503-101218.554732     regression_dnn
# 9   auto-mpg-postgres  20210503-102124.944080     regression_dnn
# 10  auto-mpg-postgres  20210503-102406.188624     regression_dnn
# 11  auto-mpg-postgres  20210503-102745.642684     regression_dnn
# 12  auto-mpg-postgres  20210503-103853.212040     regression_dnn
# 13  auto-mpg-postgres  20210503-104125.242540     regression_dnn
# 14  auto-mpg-postgres  20210503-104528.091495  regression_simple
# 15  auto-mpg-postgres  20210503-104528.091495     regression_dnn
# 16  auto-mpg-postgres  20210503-105908.893522  regression_simple
# 17  auto-mpg-postgres  20210503-105908.893522     regression_dnn
# 18  auto-mpg-postgres  20210503-110253.357855  regression_simple
# 19  auto-mpg-postgres  20210503-110253.357855     regression_dnn
# 20  auto-mpg-postgres  20210503-110652.892518     regression_dnn
# 21  auto-mpg-postgres  20210503-110652.892518  regression_simple
#
#             started_at         last_update
# 0  2021-05-03 08:42:27 2021-05-03 08:42:28
# 1  2021-05-03 08:45:33 2021-05-03 08:45:35
# 2  2021-05-03 08:52:32 2021-05-03 08:52:34
# 3  2021-05-03 09:53:27 2021-05-03 09:53:29
# 4  2021-05-03 09:59:37 2021-05-03 09:59:38
# 5  2021-05-03 10:02:08 2021-05-03 10:02:10
# 6  2021-05-03 10:04:34 2021-05-03 10:04:36
# 7  2021-05-03 10:10:00 2021-05-03 10:10:01
# 8  2021-05-03 10:14:20 2021-05-03 10:14:21
# 9  2021-05-03 10:23:19 2021-05-03 10:23:21
# 10 2021-05-03 10:25:51 2021-05-03 10:25:52
# 11 2021-05-03 10:29:34 2021-05-03 10:29:36
# 12 2021-05-03 10:40:45 2021-05-03 10:40:47
# 13 2021-05-03 10:43:16 2021-05-03 10:43:18
# 14 2021-05-03 10:47:16 2021-05-03 10:47:18
# 15 2021-05-03 10:48:08 2021-05-03 10:48:10
# 16 2021-05-03 11:00:59 2021-05-03 11:01:01
# 17 2021-05-03 11:01:52 2021-05-03 11:01:53
# 18 2021-05-03 11:04:39 2021-05-03 11:04:40
# 19 2021-05-03 11:05:27 2021-05-03 11:05:29
# 20 2021-05-03 11:08:39 2021-05-03 11:08:41
# 21 2021-05-03 11:09:23 2021-05-03 11:09:24
